# %%
import osmnx as ox
import random
import heapq

# %%
place_name = "Santa Ana, San José, Costa Rica"
G = ox.graph_from_place(place_name, network_type="drive")

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
